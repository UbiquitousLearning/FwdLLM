# %%
train_time = 1
param_num = 450340
comm_bandwidth = 10 * 1024**2 /8  # k * 1024**2 /8 => k Mb/s 
comm_time = param_num * 4 / comm_bandwidth
fwdgrad_time_per_round = train_time*15 + comm_time*15
fedsgd_time_per_round = train_time*8*15 + comm_time*15*2
fedavg_time_per_round = train_time*8*15 + comm_time*1*2
fwdgrad_time_per_round /= 60
fedsgd_time_per_round /= 60
fedavg_time_per_round /= 60
method_round_time = [fedavg_time_per_round,fedsgd_time_per_round,fwdgrad_time_per_round]
dataset = "agnews"

# %%
import matplotlib.pyplot as plt
import numpy as np

linestyle = [(0, ( )), (0, (3, 1,1,1,1,1)), (0, (4, 1,1,1)), (0, (1, 1)),(0, (2, 4)), (0, (5, 1)),(0,(3,1,3,1)),(0,(4,3,3,1))]
colors=['r','g','b','y','c','m','k',"tan"] * 100
lw = 3
client_num_list = [50]
method_list = ["fedFwd"]
model_list = ["distilbert"]
# normal_method_list = ["kaiming_normal", "xavier_normal"]
learning_rate_list = ["0.01"]
h_list = ["1e-2","1e-3","1e-4"]
eval_frequence = 1
for model in model_list:
    # for method in normal_method_list:
    # k = 1
    # plt.figure(figsize=(30, 6),dpi=100)
    for lr in learning_rate_list:
        for method_id,method in enumerate(method_list):
            acc_lists = []
            for i,client_num in enumerate(client_num_list):
                for j,h in enumerate(h_list):
                    acc = []
                    with open(f"{method}_{model}_{dataset}_lr{lr}_client_num_{client_num}_h={h}.log","r") as f:
                        log = f.readlines()
                        for l in log:
                            if "'acc':" in l:
                                acc.append(float(l[l.rfind("'acc':")+7:l.rfind(",")]))
                            # if len(acc)>200:
                            #     break
                    plt.plot([t*method_round_time[method_id]*eval_frequence for t in range(len(acc))], acc, linestyle=linestyle[i+j], color=colors[method_id+j],label=f"{method} client_num {client_num} h={h}",linewidth=lw)

                    acc = []
                    with open(f"./{method}_{model}_{dataset}_lr{lr}_client_num_{client_num}_h={h}.log","r") as f:
                        log = f.readlines()
                        for l in log:
                            if "'acc':" in l:
                                acc.append(float(l[l.rfind("'acc':")+7:l.rfind(",")]))
                            # if len(acc)>200:
                            #     break
                    plt.plot([t*method_round_time[method_id]*eval_frequence for t in range(len(acc))], acc, linestyle=linestyle[-i-j-1], color=colors[-method_id-j-1],label=f"{method} client_num {client_num} h={h} bilateral",linewidth=lw)

                acc = []
                with open(f"../distilbert_agnews/{method}_{model}_{dataset}_lr{lr}_client_num_{client_num}.log","r") as f:
                    log = f.readlines()
                    for l in log:
                        if "'acc':" in l:
                            acc.append(float(l[l.rfind("'acc':")+7:l.rfind(",")]))
                        # if len(acc)>200:
                        #     break
                plt.plot([t*method_round_time[method_id]*eval_frequence for t in range(len(acc))], acc, linestyle=linestyle[i+1], color=colors[method_id+1],label=f"{method} client_num {client_num}",linewidth=lw)
        
        plt.xlabel("Time(min)",fontsize=20)
        plt.ylabel("Acc.",fontsize=20)
        plt.xticks(size = 20)
        plt.xlim(0,50)
        plt.yticks(size = 20)
        plt.ylim(0.2,0.92)
        plt.legend(fontsize=8)
        plt.title(f"{model} {dataset}",fontsize=30)
    plt.show()
        # plt.savefig(f"./{model}_{method}.pdf")

# %%
import matplotlib.pyplot as plt
import numpy as np

linestyle = [(0, ( )), (0, (3, 1,1,1,1,1)), (0, (4, 1,1,1)), (0, (1, 1)),(0, (2, 4)), (0, (5, 1)),(0,(3,1,3,1)),(0,(4,3,3,1))]
colors=['r','g','b','y','c','m','k',"tan"] * 100
lw = 3
client_num_list = [200]
method_list = ["fedFwd"]
model_list = ["distilbert"]
# normal_method_list = ["kaiming_normal", "xavier_normal"]
learning_rate_list = ["0.01"]
h_list = ["1e-2","1e-3","1e-4"]
eval_frequence = 1
for model in model_list:
    # for method in normal_method_list:
    # k = 1
    # plt.figure(figsize=(30, 6),dpi=100)
    for lr in learning_rate_list:
        for method_id,method in enumerate(method_list):
            acc_lists = []
            for i,client_num in enumerate(client_num_list):
                for j,h in enumerate(h_list):
                    acc = []
                    with open(f"{method}_{model}_{dataset}_lr{lr}_client_num_{client_num}_h={h}.log","r") as f:
                        log = f.readlines()
                        for l in log:
                            if "'acc':" in l:
                                acc.append(float(l[l.rfind("'acc':")+7:l.rfind(",")]))
                            # if len(acc)>200:
                            #     break
                    plt.plot([t*method_round_time[method_id]*eval_frequence for t in range(len(acc))], acc, linestyle=linestyle[i+j], color=colors[method_id+j],label=f"{method} client_num {client_num} h={h}",linewidth=lw)

                    acc = []
                    with open(f"./{method}_{model}_{dataset}_lr{lr}_client_num_{client_num}_h={h}.log","r") as f:
                        log = f.readlines()
                        for l in log:
                            if "'acc':" in l:
                                acc.append(float(l[l.rfind("'acc':")+7:l.rfind(",")]))
                            # if len(acc)>200:
                            #     break
                    plt.plot([t*method_round_time[method_id]*eval_frequence for t in range(len(acc))], acc, linestyle=linestyle[-i-j-1], color=colors[-method_id-j-1],label=f"{method} client_num {client_num} h={h} bilateral",linewidth=lw)

                acc = []
                with open(f"../distilbert_agnews/{method}_{model}_{dataset}_lr{lr}_client_num_{client_num}.log","r") as f:
                    log = f.readlines()
                    for l in log:
                        if "'acc':" in l:
                            acc.append(float(l[l.rfind("'acc':")+7:l.rfind(",")]))
                        # if len(acc)>200:
                        #     break
                plt.plot([t*method_round_time[method_id]*eval_frequence for t in range(len(acc))], acc, linestyle=linestyle[i+1], color=colors[method_id+1],label=f"{method} client_num {client_num}",linewidth=lw)
        
        plt.xlabel("Time(min)",fontsize=20)
        plt.ylabel("Acc.",fontsize=20)
        plt.xticks(size = 20)
        plt.xlim(0,50)
        plt.yticks(size = 20)
        plt.ylim(0.2,0.92)
        plt.legend(fontsize=8)
        plt.title(f"{model} {dataset}",fontsize=30)
    plt.show()
        # plt.savefig(f"./{model}_{method}.pdf")
