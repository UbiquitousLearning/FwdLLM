# %%
train_time = 1
param_num = 450340
local_data_num = 18
comm_bandwidth = 10 * 1024**2 /8  # k * 1024**2 /8 => k Mb/s 
comm_time = param_num * 4 / comm_bandwidth
fwdgrad_time_per_round = train_time*local_data_num*7 + comm_time*local_data_num
fedsgd_time_per_round = train_time*8*local_data_num + comm_time*local_data_num*2
fedavg_time_per_round = train_time*8*local_data_num + comm_time*1*2
fwdgrad_time_per_round /= 60
fedsgd_time_per_round /= 60
fedavg_time_per_round /= 60
method_round_time = [fedavg_time_per_round,fedsgd_time_per_round,fwdgrad_time_per_round]
method_to_time = {"fedFwd":fwdgrad_time_per_round,"fedsgd":fedsgd_time_per_round,"fedavg":fedavg_time_per_round}
dataset = "yahoo"

# %%
import os 
import sys
import matplotlib.pyplot as plt
import numpy as np

eval_frequence = 5
linestyle = [(0, ( )), (0, (3, 1,1,1,1,1)), (0, (4, 1,1,1)), (0, (1, 1)),(0, (2, 4)), (0, (5, 1)),(0,(3,1,3,1)),(0,(4,3,3,1))]*100
colors=['r','g','b','y','c','m','k',"tan"] * 100
lw = 3
step = 0

method_to_time["fedFwd"] = (train_time*local_data_num + comm_time*local_data_num)/60
logdir = "/data/wyz/FedNLP/experiments/distributed/transformer_exps/run_tc_exps/log/distilbert_yahoo_client_10000"
for i,file in enumerate(sorted(os.listdir(logdir))):
    if file.endswith(".log"):
        acc = []
        with open(logdir+"/"+file,"r") as f:
            log = f.readlines()
            for l in log:
                if "'acc':" in l:
                    acc.append(float(l[l.rfind("'acc':")+7:l.rfind(",")]))
                # if len(acc)>200:
                #     break
            method = file.split("_")[0]
            plt.plot([t*method_to_time[method]*eval_frequence for t in range(len(acc))], acc, linestyle=linestyle[i-step], color=colors[i-step],label=file.replace(".log","").replace("fedFwd_distilbert_yahoo_","").replace("fedsgd_distilbert_yahoo_",""),linewidth=lw)
    elif file.endswith(".bak"):
        step += 1
method_to_time["fedFwd"] = (train_time*local_data_num*7 + comm_time*local_data_num)/60

for j,file in enumerate(sorted(os.listdir(os.getcwd()))):
    if file.endswith(".log"):
        acc = []
        with open(file,"r") as f:
            log = f.readlines()
            for l in log:
                if "'acc':" in l:
                    acc.append(float(l[l.rfind("'acc':")+7:l.rfind(",")]))
                # if len(acc)>200:
                #     break
            method = file.split("_")[0]
            plt.plot([t*method_to_time[method]*eval_frequence for t in range(len(acc))], acc, linestyle=linestyle[i+j-step], color=colors[i+j-step],label=file.replace(".log","").replace("fedFwd_distilbert_yahoo_","").replace("fedSgd_distilbert_yahoo_","")+"_split_concat",linewidth=lw)
    elif file.endswith(".bak"):
        step += 1
plt.xlabel("Time(min)",fontsize=20)
plt.ylabel("Acc.",fontsize=20)
plt.xticks(size = 20)
plt.xlim(0,250)
plt.yticks(size = 20)
plt.ylim(0.1,0.8)
plt.legend(fontsize=8)
plt.title(f"distilbert yahoo",fontsize=30)
plt.show()

# %%
import os 
import sys
import matplotlib.pyplot as plt
import numpy as np

eval_frequence = 5
linestyle = [(0, ( )), (0, (3, 1,1,1,1,1)), (0, (4, 1,1,1)), (0, (1, 1)),(0, (2, 4)), (0, (5, 1)),(0,(3,1,3,1)),(0,(4,3,3,1))]
colors=['r','g','b','y','c','m','k',"tan"] * 100
lw = 3

for i,file in enumerate(sorted(os.listdir(os.getcwd()))):
    if file.endswith(".log"):
        acc = []
        with open(file,"r") as f:
            log = f.readlines()
            for l in log:
                if "'acc':" in l:
                    acc.append(float(l[l.rfind("'acc':")+7:l.rfind(",")]))
                # if len(acc)>200:
                #     break
            method = file.split("_")[0]
            plt.plot([t*method_to_time[method]*eval_frequence for t in range(len(acc))], acc, linestyle=linestyle[i], color=colors[i],label=file,linewidth=lw)

plt.xlabel("Time(min)",fontsize=20)
plt.ylabel("Acc.",fontsize=20)
plt.xticks(size = 20)
plt.xlim(0,250)
plt.yticks(size = 20)
plt.ylim(0.1,0.98)
plt.legend(fontsize=8)
plt.title(f"distilbert yahoo",fontsize=30)
plt.show()

# %%
import os 
import sys
import matplotlib.pyplot as plt
import numpy as np

eval_frequence = 5
linestyle = [(0, ( )), (0, (3, 1,1,1,1,1)), (0, (4, 1,1,1)), (0, (1, 1)),(0, (2, 4)), (0, (5, 1)),(0,(3,1,3,1)),(0,(4,3,3,1))]
colors=['r','g','b','y','c','m','k',"tan"] * 100
lw = 3

for i,file in enumerate(sorted(os.listdir(os.getcwd()))):
    if file.endswith(".log"):
        acc = []
        with open(file,"r") as f:
            log = f.readlines()
            for l in log:
                if "'acc':" in l:
                    acc.append(float(l[l.rfind("'acc':")+7:l.rfind(",")]))
                # if len(acc)>200:
                #     break
            method = file.split("_")[0]
            plt.plot([t*eval_frequence for t in range(len(acc))], acc, linestyle=linestyle[i], color=colors[i],label=file,linewidth=lw)

plt.xlabel("Round",fontsize=20)
plt.ylabel("Acc.",fontsize=20)
plt.xticks(size = 20)
plt.xlim(0,250)
plt.yticks(size = 20)
plt.ylim(0.2,0.98)
plt.legend(fontsize=8)
plt.title(f"distilbert yahoo",fontsize=30)
plt.show()
