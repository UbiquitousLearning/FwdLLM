# %%
logging_file_dict = {
    "distilbert agnews":
        {
        "ours":"./distilbert_agnews/fedFwd_distilbert_agnews_lr0.01_client_num_1000_numerical.log",
        'fedadapter':'./distilbert_agnews/fedsgd_distilbert_agnews_lr0.01_client_num_10_fedadapter_2_layer.log',
        "adapter":"./distilbert_agnews/fedsgd_distilbert_agnews_lr0.01_client_num_10_adapter.log",
        "bitfit":"./distilbert_agnews/fedsgd_distilbert_agnews_lr0.01_client_num_10_bitfit.log",
        "full":"./distilbert_agnews/fedsgd_distilbert_agnews_lr0.01_client_num_10_full.log"
            },
    "distilbert yahoo":
        {
    "ours":"./distilbert_yahoo/fedFwd_distilbert_yahoo_lr0.01_client_num_5000_numerical.log",
    'fedadapter':'./distilbert_yahoo/fedsgd_distilbert_yahoo_lr0.01_client_num_10_fedadapter_2_layer.log',
    "adapter":"./distilbert_yahoo/fedsgd_distilbert_yahoo_lr0.01_client_num_100_adapter.log",
    "bitfit":"./distilbert_yahoo/fedsgd_distilbert_yahoo_lr0.01_client_num_10_bitfit.log",
    "full":"./distilbert_yahoo/fedsgd_distilbert_yahoo_lr0.01_client_num_10_full.log"
            },
    "distilbert yelp-p":
        {
    "ours":"./distilbert_yelp-p/fedFwd_distilbert_yelp-p_lr0.01_client_num_1000_numerical.log",
    'fedadapter':'./distilbert_yelp-p/fedsgd_distilbert_yelp-p_lr0.01_client_num_10_fedadapter_2_layer.log',
    "adapter":"./distilbert_yelp-p/fedsgd_distilbert_yelp-p_lr0.01_client_num_10_adapter.log",
    "bitfit":"./distilbert_yelp-p/fedsgd_distilbert_yelp-p_lr0.01_client_num_10_bitfit.log",
    "full":"./distilbert_yelp-p/fedsgd_distilbert_yelp-p_lr0.01_client_num_10_full.log"
            },
    "bert agnews":
        {
    "ours":"./bert_agnews/fedFwd_bert_agnews_lr0.01_client_num_1000_numerical.log",
    'fedadapter':'./bert_agnews/fedsgd_bert_agnews_lr0.01_client_num_10_fedadapter_2_layer.log',
    "adapter":"./bert_agnews/fedsgd_bert_agnews_lr0.01_client_num_10_adapter.log",
    "bitfit":"./bert_agnews/fedsgd_bert_agnews_lr0.01_client_num_10_bitfit.log",
    "full":"./bert_agnews/fedsgd_bert_agnews_lr0.01_client_num_10_full.log"
            },
    "bert yahoo":
        {
    "ours":"./bert_yahoo/fedFwd_bert_yahoo_lr0.01_client_num_1000_numerical.log",
    'fedadapter':'./bert_yahoo/fedsgd_bert_yahoo_lr0.01_client_num_10_fedadapter_3_layer.log',
    "adapter":"./bert_yahoo/fedsgd_bert_yahoo_lr0.01_client_num_10_adapter.log",
    "bitfit":"./bert_yahoo/fedsgd_bert_yahoo_lr0.01_client_num_10_bitfit.log",
    "full":"./bert_yahoo/fedsgd_bert_yahoo_lr0.01_client_num_10_full.log"
            },
    "bert yelp-p":
        {
    "ours":"./bert_yelp-p/fedFwd_bert_yelp-p_lr0.01_client_num_1000_numerical.log",
    'fedadapter':'./bert_yelp-p/fedsgd_bert_yelp-p_lr0.01_client_num_10_fedadapter_3_layer.log',
    "adapter":"./bert_yelp-p/fedsgd_bert_yelp-p_lr0.01_client_num_10_adapter.log",
    "bitfit":"./bert_yelp-p/fedsgd_bert_yelp-p_lr0.01_client_num_10_bitfit.log",
    "full":"./bert_yelp-p/fedsgd_bert_yelp-p_lr0.01_client_num_10_full.log"
            },
    "roberta-large agnews":
        {
    "ours":"./roberta-large_agnews/fedFwd_roberta-large_agnews_lr0.01_client_num_1000_numerical.log",
    'fedadapter':'./roberta-large_agnews/fedsgd_roberta-large_agnews_lr0.01_client_num_10_fedadapter_4_layer.log',
    "adapter":"./roberta-large_agnews/fedsgd_roberta-large_agnews_lr0.001_client_num_10_adapter.log",
    "bitfit":"./roberta-large_agnews/fedsgd_roberta-large_agnews_lr0.01_client_num_10_bitfit.log",
    "full":"./roberta-large_agnews/fedsgd_roberta-large_agnews_lr0.001_client_num_10_full.log"
        },
    "roberta-large yahoo":
        {
    "ours":"./roberta-large_yahoo/fedFwd_roberta-large_yahoo_lr0.01_client_num_1000_numerical.log",
    'fedadapter':'./roberta-large_yahoo/fedsgd_roberta-large_yahoo_lr0.01_client_num_10_fedadapter_4_layer.log',
    "adapter":"./roberta-large_yahoo/fedsgd_roberta-large_yahoo_lr0.01_client_num_10_adapter.log",
    "bitfit":"./roberta-large_yahoo/fedsgd_roberta-large_yahoo_lr0.01_client_num_10_bitfit.log",
    "full":"./roberta-large_yahoo/fedsgd_roberta-large_yahoo_lr0.01_client_num_10_full.log"
            },
    "roberta-large yelp-p":
        {
    "ours":"./roberta-large_yelp-p/fedFwd_roberta-large_yelp-p_lr0.01_client_num_1000_numerical.log",
    'fedadapter':'./roberta-large_yelp-p/fedsgd_roberta-large_yelp-p_lr0.01_client_num_10_fedadapter_4_layer.log',
    "adapter":"./roberta-large_yelp-p/fedsgd_roberta-large_yelp-p_lr0.001_client_num_10_adapter.log",
    "bitfit":"./roberta-large_yelp-p/fedsgd_roberta-large_yelp-p_lr0.01_client_num_10_bitfit.log",
    "full":"./roberta-large_yelp-p/fedsgd_roberta-large_yelp-p_lr0.01_client_num_10_full.log"
            },
    "albert agnews":
        {
    "ours":"./albert_agnews/fedFwd_albert_agnews_lr0.01_client_num_1000_numerical_bitfit.log",
    'fedadapter':'./albert_agnews/fedsgd_albert_agnews_lr0.01_client_num_10_fedadapter_width12.log',
    "adapter":"./albert_agnews/fedsgd_albert_agnews_lr0.01_client_num_10_lora.log",
    "bitfit":"./albert_agnews/fedsgd_albert_agnews_lr0.01_client_num_10_bitfit.log",
    "full":"./albert_agnews/fedsgd_albert_agnews_lr0.01_client_num_10_full.log"
            },
    "albert yahoo":
        {
    "ours":"./albert_yahoo/fedFwd_albert_yahoo_lr0.01_client_num_1000_numerical_bitfit.log",
    'fedadapter':'./albert_yahoo/fedsgd_albert_yahoo_lr0.01_client_num_10_fedadapter_width12.log',
    "adapter":"./albert_yahoo/fedsgd_albert_yahoo_lr0.01_client_num_10_lora.log",
    "bitfit":"./albert_yahoo/fedsgd_albert_yahoo_lr0.01_client_num_10_bitfit.log",
    "full":"./albert_yahoo/fedsgd_albert_yahoo_lr0.01_client_num_10_full.log"
            },
    "albert yelp-p":
    {
    "ours":"./albert_yelp-p/fedFwd_albert_yelp-p_lr0.01_client_num_1000_numerical_bitfit.log",
    'fedadapter':'./albert_yelp-p/fedsgd_albert_yelp-p_lr0.01_client_num_10_fedadapter_width24.log',
    "adapter":"./albert_yelp-p/fedsgd_albert_yelp-p_lr0.01_client_num_10_lora.log",
    "bitfit":"./albert_yelp-p/fedsgd_albert_yelp-p_lr0.01_client_num_10_bitfit.log",
    "full":"./albert_yelp-p/fedsgd_albert_yelp-p_lr0.01_client_num_10_full.log"
        }
}

train_time_dict_dict = {
    "distilbert":{"ours":0.3085584,'fedadapter':1.3878,"adapter":4.1634,"bitfit":4.1634,"full":6.939},
    "bert":{"ours":0.669904,'fedadapter':2.055875,"adapter":8.2235,"bitfit":8.2235,"full":14.047},
    "albert":{"ours":0.6384,'fedadapter':10,"adapter":10.5156,"bitfit":10.5156,"full":17.526},
    "roberta-large":{"ours":0.669904*2,'fedadapter':2.74117*2,"adapter":8.2235*2,"bitfit":8.2235*2,"full":14.047*2}
}

axis_setting_dict = {
    'albert-agnews': (200,0.95),
    'distilbert-agnews':(100,0.95),
    'bert-agnews':(200,0.95),
    'roberta-large-agnews':(200,0.95),
    'albert-yahoo':(600,0.78),
    'distilbert-yahoo':(200,0.8),
    'bert-yahoo':(600,0.8),
    'roberta-large-yahoo':(400,0.8),
    'albert-yelp-p':(500,0.9),
    'distilbert-yelp-p':(400,0.9),
    'bert-yelp-p':(400,0.9),
    'roberta-large-yelp-p':(400,0.9)
}

# gpu
# train_time_dict_dict = {
#     "distilbert":{"ours":0.7837*2,'fedadapter':1.3878,"adapter":4.1634,"bitfit":4.1634,"full":6.939},
#     "bert":{"ours":0.7978*2,'fedadapter':2.055875,"adapter":8.2235,"bitfit":8.2235,"full":14.047},
#     "albert":{"ours":1.5492*2,'fedadapter':10,"adapter":10.5156,"bitfit":10.5156,"full":17.526},
#     "roberta-large":{"ours":2.8661*2,'fedadapter':2.74117*2,"adapter":8.2235*2,"bitfit":8.2235*2,"full":14.047*2}
# }
# tx2 gpu
# ratio = 5.8
# train_time_dict_dict = {
#     "distilbert":{"ours":3.35942/ratio,'fedadapter':1.3878/ratio,"adapter":4.1634/ratio,"bitfit":4.163/ratio,"full":6.939/ratio},
#     "bert":{"ours":6.91072/ratio,'fedadapter':2.055875/ratio,"adapter":8.2235/ratio,"bitfit":8.2235/ratio,"full":14.047/ratio},
#     "albert":{"ours":6.73988/ratio,'fedadapter':10/ratio,"adapter":10.5156/ratio,"bitfit":10.5156/ratio,"full":17.526/ratio},
#     "roberta-large":{"ours":6.91072*2/ratio,'fedadapter':2.74117*2/ratio,"adapter":8.2235*2/ratio,"bitfit":8.2235*2/ratio,"full":14.047*2/ratio}
# }

device = "NPU"
# device = "CPU"
cpu_infer_time = {"distilbert":3.35942,"bert":6.91072,"albert":6.73988,"roberta-large":6.91072*2}

if device == "CPU":
    for model in train_time_dict_dict:
        train_time_dict_dict[model]["ours"] = cpu_infer_time[model]

local_data_num_dict = {"agnews":15,"yahoo":18,"yelp-p":65}

# %%
import os 
import sys
import matplotlib.pyplot as plt
import numpy as np

def plot_end_to_end(model,dataset,target_acc, path=f"/data/wyz/ForwardFL-Latex/figs"):
    logging_file = logging_file_dict[f"{model} {dataset}"]
    train_time_dict = train_time_dict_dict[model]
    local_data_num = local_data_num_dict[dataset]

    comm_bandwidth = 10 * 1024**2 /8  # k * 1024**2 /8 => k Mb/s 
    time_to_acc_dict ={}
    
    eval_frequence = 5 if dataset == "yahoo" else 1
    # linestyle = [(0, ( )), (0, (3, 1,1,1,1,1)), (0, (4, 1,1,1)), (0, (1, 1)),(0, (2, 4)), (0, (5, 1)),(0,(3,1,3,1)),(0,(4,3,3,1))]*100
    # colors=['darkred','g','b','y','c','m','k',"tan"] * 100
    color_map = {'ours': 'darkred','fedadapter': 'g','adapter': 'b','bitfit': 'y','full': 'c'}
    linestyle_map = {'ours': (0, ()),'fedadapter': (0, (3, 1, 1, 1, 1, 1)),'adapter': (0, (4, 1, 1, 1)),'bitfit': (0, (1, 1)),'full': (0, (2, 4))}
    lw = 8

    def round_to_time(round,eval_frequence,comm_time,method,local_data_num,adhoc=None):
        train_time = train_time_dict[method]
        if adhoc == None:
            adhoc = [1,1,1]
        else:
            adhoc = list(map(int,adhoc.split(",")))
        time_list = [0]
        if method == "ours":
            time = (train_time*local_data_num*adhoc[0] + comm_time*local_data_num)/60
        else:
            time = (train_time*local_data_num*adhoc[0] + 2*comm_time*local_data_num)/60
        time_list.append(time)
        for i in range(2,round):
            v_num = adhoc[i-1] if i-1 < len(adhoc) else adhoc[-1]
            if method == "ours":
                time += (train_time*local_data_num*v_num*eval_frequence + comm_time*local_data_num)/60
            else:
                time += (train_time*local_data_num*v_num*eval_frequence + 2*comm_time*local_data_num)/60
            time_list.append(time)
        return time_list
        
    def get_time_to_target_acc(target_acc,acc_list,time_list):
        n = len(acc_list)
        i = 0
        while i < n and acc_list[i] < target_acc:
            i += 1
        return time_list[i] if i<n else 10000
    method_list = ['full','adapter','bitfit','fedadapter','ours',]
    for i,method in enumerate(method_list):
        file = logging_file[method]
        with open(file) as f:
            max_acc = 0
            for line in f:
                if "Trainable" in line:
                    param_num = int(line[line.rfind(":")+2:-2])
                    print(f"param_num: {param_num}")
                    break
            comm_time = param_num * 4 / comm_bandwidth
            acc = [0]
            if "," in file:
                adhoc = file.split("_")[-1].split(".")[0]
            else:
                adhoc = None
            for line in f:
                if "'acc':" in line:
                    cur_acc = float(line[line.rfind("'acc':")+7:line.rfind(",")])
                    if cur_acc > max_acc:
                        max_acc = cur_acc
                    else:
                        cur_acc = max_acc
                    acc.append(cur_acc)
            time_list = round_to_time(len(acc),eval_frequence,comm_time,method,local_data_num,adhoc)
            time_to_acc_dict[method] = get_time_to_target_acc(target_acc,acc,time_list)
            label_dict = {'ours':'Ours','full':'Full-FT','fedadapter':'FedAdapter','adapter':'Adapter','bitfit':'BitFit'}
            plt.plot(time_list, acc, linestyle=linestyle_map[method], color=color_map[method],label=label_dict[method],linewidth=lw)
    
    print(f"time to target acc {target_acc}: {time_to_acc_dict}")

    plt.xlabel("Elapsed Training Time (mins)",fontsize=29)
    plt.ylabel("Accuracy",fontsize=30)
    plt.xticks(fontsize = 25)
    max_x, max_y = axis_setting_dict[f'{model}-{dataset}']
    plt.xlim(0,max_x)
    plt.yticks(np.arange(0,max_y,0.2),fontsize = 25)
    if max_x == 400:
        plt.xticks(range(0,max_x+1,100),fontsize = 25)
    elif max_x == 200:
        plt.xticks(range(0,max_x+1,50),fontsize = 25)
    plt.ylim(0,max_y)
    if f'{model}-{dataset}' == 'albert-agnews':
        plt.legend(fontsize=30,ncol=5,loc=4,frameon=False,bbox_to_anchor=(4.5,1.1))
    title_dict = {'albert':"ALBERT-base","distilbert":"DistilBERT-base","bert":"BERT-base",'roberta-large':'RoBERTa-large'}
    plt.title(f"{title_dict[model]}",fontsize=30)
    # plt.savefig(f"{path}/eval-e2e-{model}-{dataset}.pdf", bbox_inches="tight")
    plt.show()

    # # 提取键和值的列表
    # keys = list(time_to_acc_dict.keys())
    # values = list(time_to_acc_dict.values())

    # # 绘制柱状图
    # plt.bar(keys, values)

    # # 设置坐标轴标签和标题
    # plt.xlabel('method')
    # plt.ylabel(f'time to target acc {target_acc}')
    # plt.title('Bar Chart')

    # 显示图形
    # plt.savefig(f"{path}/eval-bar-e2e-{model}-{dataset}.pdf", bbox_inches="tight")
    # plt.show()
    return time_to_acc_dict

# %%
models = ['albert','distilbert','bert','roberta-large']
datasets = ['agnews','yahoo','yelp-p']
acc_threhold = {
    'albert-agnews': 0.875,
    'distilbert-agnews':0.875,
    'bert-agnews':0.875,
    'roberta-large-agnews':0.875,
    'albert-yahoo':0.65,
    'distilbert-yahoo':0.7,
    'bert-yahoo':0.69,
    'roberta-large-yahoo':0.65,
    'albert-yelp-p':0.82,
    'distilbert-yelp-p':0.82,
    'bert-yelp-p':0.83,
    'roberta-large-yelp-p':0.82
}
runtime = {}
for model in models:
    for dataset in datasets:
        runtime.update({f"{model}-{dataset}": plot_end_to_end(model,dataset,acc_threhold[f"{model}-{dataset}"])})
# Out:
# param_num: 11686660
# param_num: 27652
# param_num: 13188
# param_num: 2228
# param_num: 13188
# time to target acc 0.875: {'full': 4598.2830915527375, 'adapter': 168.2788970214845, 'bitfit': 174.8355372070312, 'fedadapter': 187.75497436523455, 'ours': 22.73466049804684}
# param_num: 11691274
# param_num: 32266
# param_num: 17802
# param_num: 2690
# param_num: 17802
# time to target acc 0.65: {'full': 1075.9851273925785, 'adapter': 509.8531467480471, 'bitfit': 350.9191980175783, 'fedadapter': 303.103436279297, 'ours': 30.39866296875001}
# param_num: 11685122
# param_num: 26114
# param_num: 11650
# param_num: 4073
# param_num: 11650
# time to target acc 0.82: {'full': 5871.261291056319, 'adapter': 948.2946968912769, 'bitfit': 367.0058065104167, 'fedadapter': 293.2271438598634, 'ours': 27.01428188883462}
# param_num: 66365956
# param_num: 450340
# param_num: 54532
# param_num: 152164
# param_num: 450340
# time to target acc 0.875: {'full': 721.0081364746094, 'adapter': 84.67270102539067, 'bitfit': 76.43602753906247, 'fedadapter': 29.535825732421834, 'ours': 21.877531172656244}
# param_num: 66370570
# param_num: 454954
# param_num: 59146
# param_num: 156778
# param_num: 454954
# time to target acc 0.7: {'full': 651.3564165527343, 'adapter': 115.33239612304688, 'bitfit': 134.77871033203127, 'fedadapter': 59.92263638671878, 'ours': 18.09629889011719}
# param_num: 66364418
# param_num: 448802
# param_num: 52994
# param_num: 150626
# param_num: 448802
# time to target acc 0.82: {'full': 892.6564014485677, 'adapter': 119.64628033854164, 'bitfit': 116.65809238281248, 'fedadapter': 52.487620288085935, 'ours': 32.724771490429696}
# param_num: 109485316
# param_num: 897604
# param_num: 105988
# param_num: 152164
# param_num: 105988
# time to target acc 0.875: {'full': 1535.1577580566407, 'adapter': 250.06223071289043, 'bitfit': 272.7647819824218, 'fedadapter': 89.53831054687491, 'ours': 27.565565370117127}
# param_num: 109489930
# param_num: 902218
# param_num: 110602
# param_num: 156778
# param_num: 110602
# time to target acc 0.69: {'full': 1090.9063478027342, 'adapter': 311.8387914550781, 'bitfit': 366.26484931640636, 'fedadapter': 176.1896743652345, 'ours': 48.97129718730464}
# param_num: 109483778
# param_num: 896066
# param_num: 104450
# param_num: 150626
# param_num: 104450
# time to target acc 0.83: {'full': 2217.4195865478514, 'adapter': 370.84268086751285, 'bitfit': 307.18175651041673, 'fedadapter': 212.7284548339844, 'ours': 33.20250180973306}
# param_num: 354314244
# param_num: 3175940
# param_num: 275460
# param_num: 532740
# param_num: 275460
# time to target acc 0.875: {'full': 3833.6489177246094, 'adapter': 859.9535859375003, 'bitfit': 58.91689184570313, 'fedadapter': 39.302671113281235, 'ours': 28.890898993164086}
# param_num: 354320394
# param_num: 3182090
# param_num: 281610
# param_num: 281610
# param_num: 281610
# time to target acc 0.65: {'full': 10000, 'adapter': 132.7490040527344, 'bitfit': 131.38045986328123, 'fedadapter': 45.85611186328125, 'ours': 30.13770157382814}
# param_num: 354312194
# param_num: 3173890
# param_num: 273410
# param_num: 273410
# param_num: 273410
# time to target acc 0.82: {'full': 66449.53503694663, 'adapter': 1319.329012125652, 'bitfit': 196.25409057617188, 'fedadapter': 77.47027390950521, 'ours': 14.132229172851563}

# %%
max(v['fedadapter']/v['ours'] for k,v in runtime.items())
# Out:
# 1.0797004595353044

# %%
t1 = map(float,'1325.6 	2147.9 	1119.6 	136.9 	485.7 	141.2 	595.2 	1718.6 	704.6 	298.1 	1067.0 	410.4'.split())
t2 = map(float,'168.3 	509.9 	948.3 	84.7 	115.3 	119.6 	250.1 	311.8 	370.8 	860.0 	132.7 	1319.3'.split())

# %%
[a/b for a,b in zip(t1,t2)]
# Out:
# [7.876411170528817,
#  4.212394587173956,
#  1.1806390382790255,
#  1.61629279811098,
#  4.212489158716392,
#  1.180602006688963,
#  2.3798480607756898,
#  5.511866581141757,
#  1.900215749730313,
#  0.3466279069767442,
#  8.040693293142427,
#  0.31107405442279995]

# %%
linestyle = [(0, ( )), (0, (3, 1,1,1,1,1)), (0, (4, 1,1,1)), (0, (1, 1)),(0, (2, 4)), (0, (5, 1)),(0,(3,1,3,1)),(0,(4,3,3,1))]*100
colors=['darkred','g','b','y','c','m','k',"tan"] * 100
method_list = ['ours','fedadapter','adapter','bitfit','full']

# %%
{method:color for method,color in zip(method_list,linestyle)}
# Out:
# {'ours': (0, ()),
#  'fedadapter': (0, (3, 1, 1, 1, 1, 1)),
#  'adapter': (0, (4, 1, 1, 1)),
#  'bitfit': (0, (1, 1)),
#  'full': (0, (2, 4))}

# %%
runtime
# Out:
# {'albert-agnews': {'full': 4598.2830915527375,
#   'adapter': 168.2788970214845,
#   'bitfit': 174.8355372070312,
#   'fedadapter': 187.75497436523455,
#   'ours': 22.73466049804684},
#  'albert-yahoo': {'full': 1075.9851273925785,
#   'adapter': 509.8531467480471,
#   'bitfit': 350.9191980175783,
#   'fedadapter': 303.103436279297,
#   'ours': 30.39866296875001},
#  'albert-yelp-p': {'full': 5871.261291056319,
#   'adapter': 948.2946968912769,
#   'bitfit': 367.0058065104167,
#   'fedadapter': 293.2271438598634,
#   'ours': 27.01428188883462},
#  'distilbert-agnews': {'full': 721.0081364746094,
#   'adapter': 84.67270102539067,
#   'bitfit': 76.43602753906247,
#   'fedadapter': 29.535825732421834,
#   'ours': 21.877531172656244},
#  'distilbert-yahoo': {'full': 651.3564165527343,
#   'adapter': 115.33239612304688,
#   'bitfit': 134.77871033203127,
#   'fedadapter': 59.92263638671878,
#   'ours': 18.09629889011719},
#  'distilbert-yelp-p': {'full': 892.6564014485677,
#   'adapter': 119.64628033854164,
#   'bitfit': 116.65809238281248,
#   'fedadapter': 52.487620288085935,
#   'ours': 32.724771490429696},
#  'bert-agnews': {'full': 1535.1577580566407,
#   'adapter': 250.06223071289043,
#   'bitfit': 272.7647819824218,
#   'fedadapter': 89.53831054687491,
#   'ours': 27.565565370117127},
#  'bert-yahoo': {'full': 1090.9063478027342,
#   'adapter': 311.8387914550781,
#   'bitfit': 366.26484931640636,
#   'fedadapter': 176.1896743652345,
#   'ours': 48.97129718730464},
#  'bert-yelp-p': {'full': 2217.4195865478514,
#   'adapter': 370.84268086751285,
#   'bitfit': 307.18175651041673,
#   'fedadapter': 212.7284548339844,
#   'ours': 33.20250180973306},
#  'roberta-large-agnews': {'full': 3833.6489177246094,
#   'adapter': 859.9535859375003,
#   'bitfit': 58.91689184570313,
#   'fedadapter': 39.302671113281235,
#   'ours': 28.890898993164086},
#  'roberta-large-yahoo': {'full': 10000,
#   'adapter': 132.7490040527344,
#   'bitfit': 131.38045986328123,
#   'fedadapter': 45.85611186328125,
#   'ours': 30.13770157382814},
#  'roberta-large-yelp-p': {'full': 66449.53503694663,
#   'adapter': 1319.329012125652,
#   'bitfit': 196.25409057617188,
#   'fedadapter': 77.47027390950521,
#   'ours': 14.132229172851563}}

# %%
np.array([case['full']/case['ours'] for k,case in runtime.items() if case['full']/60<100]).max()
# np.array([case['full'] for k,case in runtime.items() if case['full']/60<100]).min()/60
# Out:
# 217.33915842060543

# %%
np.array([(case['adapter']+case['bitfit']+case['fedadapter'])/3/case['ours'] for k,case in runtime.items()]).mean()
# Out:
# 10.514335020600667

# %%
train_time_dict_dict
[case['adapter']/case['ours']*2 for k,case in train_time_dict_dict.items() if 'albert' not in k]
# Out:
# [2.4786421465610133, 2.379925680681607, 2.379925680681607]

# %%
# max
np.array([max(case['adapter'],case['bitfit'],case['fedadapter'])/case['ours'] for k,case in runtime.items()])
# Out:
# array([ 8.25853434, 16.77222275, 35.10345753,  3.87030421,  7.44786053,
#         3.65613799,  9.89512743,  7.47917393, 11.16911861, 29.76555303,
#         4.40474877, 93.35604426])

# %%
# min
np.array([min(case['adapter'],case['bitfit'],case['fedadapter'])/case['ours'] for k,case in runtime.items()])
# Out:
# array([0.7408786 , 0.95934618, 1.07970046, 0.47995506, 0.54210279,
#        0.56917774, 0.44602296, 0.38075521, 0.87618328, 0.2023069 ,
#        0.16538193, 0.81322661])

# %%
np.array([(case['adapter']+case['bitfit']+case['fedadapter'])/3/case['ours'] for k,case in runtime.items()]).mean()
# Out:
# 1.4532345258542378

# %%
import numpy as np
memory = {"RoBERTa-large": np.array([7.741, 5.362, 5.083, 1.490]),
 "BERT-base": np.array([2.750, 1.908, 1.860, 0.524]),
 "DistilBERT-base": np.array([1.485, 0.962, 1.003, 0.356]),
 "ALBERT-base": np.array([2.458, 1.937, 1.951, 0.169]),}
#  "LLAMA": np.array([(78-28)/2+28/8, 25.889-14+14/4, 14.959/4])}
np.array([m[0]/m[3] for k,m in memory.items()]).max()
# np.array([(m[1]+m[2])/2/m[3] for k,m in memory.items()]).mean()
# Out:
# 14.544378698224852
